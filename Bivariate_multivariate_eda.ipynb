# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulqadoos861/GetData_practice_ML/blob/main/Bivariate_multivariate_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
tip = sns.load_dataset("tips")

# %%
titanic = sns.load_dataset("titanic")

# %%
flights = sns.load_dataset("flights")

# %%
iris = sns.load_dataset("iris")

# %% [markdown]
# # Scater plot

# %% [markdown]
# Scatter plot is used when we have to show comparison between two or more numerical columns.

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x="total_bill",y="tip",data=tip , hue="sex" )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #  **Bar Plot**

# %% [markdown]
# Bar plot is used when we have to show comparison between  one numerical and one categorical coulmn.

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(x=titanic['pclass'] ,y= titanic['fare']  , hue=titanic["sex"] ,palette="rainbow")
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# Distplot

# %%
sns.distplot(titanic[titanic["survived"]==0]["age"] , hist=False)
sns.distplot(titanic[titanic["survived"]==1]["age"],hist=False)
# Out:
# /tmp/ipykernel_2812/2408303109.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic["survived"]==0]["age"] , hist=False)
# /tmp/ipykernel_2812/2408303109.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # Heatmap

# %% [markdown]
# Heatmap is used to display camparison between two categorical columns.

# %%
sns.heatmap(pd.crosstab(titanic["pclass"],titanic["survived"]))
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>
